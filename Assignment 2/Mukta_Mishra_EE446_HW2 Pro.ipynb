# %% [markdown]
# # EE446 - TinyML - Assignment 2

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from tensorflow.keras import datasets, layers,models
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Activation
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from tensorflow.keras import regularizers
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings("ignore")
from sklearn.utils import class_weight
from sklearn.metrics import accuracy_score
import c_writer
from os.path import join

# %% [markdown]
# ## Reading Data

# %%
# Reading the data and adding column header (feature) names
data = pd.read_csv("Network_anomaly_data.txt",sep=",",names=["duration","protocoltype","service",
"flag","srcbytes","dstbytes","land", "wrongfragment","urgent","hot","numfailedlogins","loggedin", "numcompromised",
"rootshell","suattempted","numroot","numfilecreations", "numshells","numaccessfiles","numoutboundcmds","ishostlogin",
"isguestlogin","count","srvcount","serrorrate", "srvserrorrate","rerrorrate","srvrerrorrate","samesrvrate",
"diffsrvrate", "srvdiffhostrate","dsthostcount","dsthostsrvcount","dsthostsamesrvrate", "dsthostdiffsrvrate",
"dsthostsamesrcportrate","dsthostsrvdiffhostrate","dsthostserrorrate","dsthostsrvserrorrate","dsthostrerrorrate",
"dsthostsrvrerrorrate","attack", "lastflag"])

# %%
data # printing the dataframe
# Out:
#         duration protocoltype   service flag  srcbytes  dstbytes  land  \
# 0              0          tcp  ftp_data   SF       491         0     0
# 1              0          udp     other   SF       146         0     0
# 2              0          tcp   private   S0         0         0     0
# 3              0          tcp      http   SF       232      8153     0
# 4              0          tcp      http   SF       199       420     0
# ...          ...          ...       ...  ...       ...       ...   ...
# 125968         0          tcp   private   S0         0         0     0
# 125969         8          udp   private   SF       105       145     0
# 125970         0          tcp      smtp   SF      2231       384     0
# 125971         0          tcp    klogin   S0         0         0     0
# 125972         0          tcp  ftp_data   SF       151         0     0
#
#         wrongfragment  urgent  hot  ...  dsthostsamesrvrate  \
# 0                   0       0    0  ...                0.17
# 1                   0       0    0  ...                0.00
# 2                   0       0    0  ...                0.10
# 3                   0       0    0  ...                1.00
# 4                   0       0    0  ...                1.00
# ...               ...     ...  ...  ...                 ...
# 125968              0       0    0  ...                0.10
# 125969              0       0    0  ...                0.96
# 125970              0       0    0  ...                0.12
# 125971              0       0    0  ...                0.03
# 125972              0       0    0  ...                0.30
#
#         dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# 0                     0.03                    0.17                    0.00
# 1                     0.60                    0.88                    0.00
# 2                     0.05                    0.00                    0.00
# 3                     0.00                    0.03                    0.04
# 4                     0.00                    0.00                    0.00
# ...                    ...                     ...                     ...
# 125968                0.06                    0.00                    0.00
# 125969                0.01                    0.01                    0.00
# 125970                0.06                    0.00                    0.00
# 125971                0.05                    0.00                    0.00
# 125972                0.03                    0.30                    0.00
#
#         dsthostserrorrate  dsthostsrvserrorrate  dsthostrerrorrate  \
# 0                    0.00                  0.00               0.05
# 1                    0.00                  0.00               0.00
# 2                    1.00                  1.00               0.00
# 3                    0.03                  0.01               0.00
# 4                    0.00                  0.00               0.00
# ...                   ...                   ...                ...
# 125968               1.00                  1.00               0.00
# 125969               0.00                  0.00               0.00
# 125970               0.72                  0.00               0.01
# 125971               1.00                  1.00               0.00
# 125972               0.00                  0.00               0.00
#
#         dsthostsrvrerrorrate   attack  lastflag
# 0                       0.00   normal        20
# 1                       0.00   normal        15
# 2                       0.00  neptune        19
# 3                       0.01   normal        21
# 4                       0.00   normal        21
# ...                      ...      ...       ...
# 125968                  0.00  neptune        20
# 125969                  0.00   normal        21
# 125970                  0.00   normal        18
# 125971                  0.00  neptune        20
# 125972                  0.00   normal        21
#
# [125973 rows x 43 columns]

# %% [markdown]
# ## Question 1: Data Preprocessing

# %% [markdown]
# ##### (a) Drop the 'land', 'urgent', 'numfailedlogins', 'numoutboundcmds' columns from the dataframe "data".

# %%
data = data.drop(columns=[
    'land',
    'urgent',
    'numfailedlogins',
    'numoutboundcmds'
])

# %% [markdown]
# ##### (b) Change any label that is not named normal to attack in the {'attack'} column of the dataframe data.

# %%
data['attack'] = data['attack'].apply(
    lambda x: 'normal' if x == 'normal' else 'attack'
)

# %%
data #<--------- Print your modified dataframe "data"
# Out:
#         duration protocoltype   service flag  srcbytes  dstbytes  \
# 0              0          tcp  ftp_data   SF       491         0
# 1              0          udp     other   SF       146         0
# 2              0          tcp   private   S0         0         0
# 3              0          tcp      http   SF       232      8153
# 4              0          tcp      http   SF       199       420
# ...          ...          ...       ...  ...       ...       ...
# 125968         0          tcp   private   S0         0         0
# 125969         8          udp   private   SF       105       145
# 125970         0          tcp      smtp   SF      2231       384
# 125971         0          tcp    klogin   S0         0         0
# 125972         0          tcp  ftp_data   SF       151         0
#
#         wrongfragment  hot  loggedin  numcompromised  ...  dsthostsamesrvrate  \
# 0                   0    0         0               0  ...                0.17
# 1                   0    0         0               0  ...                0.00
# 2                   0    0         0               0  ...                0.10
# 3                   0    0         1               0  ...                1.00
# 4                   0    0         1               0  ...                1.00
# ...               ...  ...       ...             ...  ...                 ...
# 125968              0    0         0               0  ...                0.10
# 125969              0    0         0               0  ...                0.96
# 125970              0    0         1               0  ...                0.12
# 125971              0    0         0               0  ...                0.03
# 125972              0    0         1               0  ...                0.30
#
#         dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# 0                     0.03                    0.17                    0.00
# 1                     0.60                    0.88                    0.00
# 2                     0.05                    0.00                    0.00
# 3                     0.00                    0.03                    0.04
# 4                     0.00                    0.00                    0.00
# ...                    ...                     ...                     ...
# 125968                0.06                    0.00                    0.00
# 125969                0.01                    0.01                    0.00
# 125970                0.06                    0.00                    0.00
# 125971                0.05                    0.00                    0.00
# 125972                0.03                    0.30                    0.00
#
#         dsthostserrorrate  dsthostsrvserrorrate  dsthostrerrorrate  \
# 0                    0.00                  0.00               0.05
# 1                    0.00                  0.00               0.00
# 2                    1.00                  1.00               0.00
# 3                    0.03                  0.01               0.00
# 4                    0.00                  0.00               0.00
# ...                   ...                   ...                ...
# 125968               1.00                  1.00               0.00
# 125969               0.00                  0.00               0.00
# 125970               0.72                  0.00               0.01
# 125971               1.00                  1.00               0.00
# 125972               0.00                  0.00               0.00
#
#         dsthostsrvrerrorrate  attack  lastflag
# 0                       0.00  normal        20
# 1                       0.00  normal        15
# 2                       0.00  attack        19
# 3                       0.01  normal        21
# 4                       0.00  normal        21
# ...                      ...     ...       ...
# 125968                  0.00  attack        20
# 125969                  0.00  normal        21
# 125970                  0.00  normal        18
# 125971                  0.00  attack        20
# 125972                  0.00  normal        21
#
# [125973 rows x 39 columns]

# %% [markdown]
# ##### (c) Use LabelEncoder() function from the sklearn.preprocessing library to convert non-numerical attributes in the {'protocoltype', 'service', 'flag', 'attack'} columns of the dataframe data to numerical values.

# %%
for col in ['protocoltype', 'service', 'flag', 'attack']:
    data[col] = LabelEncoder().fit_transform(data[col])

# %%
pd.DataFrame(data) #<--------- Print your modified dataframe "data"
# Out:
#         duration  protocoltype  service  flag  srcbytes  dstbytes  \
# 0              0             1       20     9       491         0
# 1              0             2       44     9       146         0
# 2              0             1       49     5         0         0
# 3              0             1       24     9       232      8153
# 4              0             1       24     9       199       420
# ...          ...           ...      ...   ...       ...       ...
# 125968         0             1       49     5         0         0
# 125969         8             2       49     9       105       145
# 125970         0             1       54     9      2231       384
# 125971         0             1       30     5         0         0
# 125972         0             1       20     9       151         0
#
#         wrongfragment  hot  loggedin  numcompromised  ...  dsthostsamesrvrate  \
# 0                   0    0         0               0  ...                0.17
# 1                   0    0         0               0  ...                0.00
# 2                   0    0         0               0  ...                0.10
# 3                   0    0         1               0  ...                1.00
# 4                   0    0         1               0  ...                1.00
# ...               ...  ...       ...             ...  ...                 ...
# 125968              0    0         0               0  ...                0.10
# 125969              0    0         0               0  ...                0.96
# 125970              0    0         1               0  ...                0.12
# 125971              0    0         0               0  ...                0.03
# 125972              0    0         1               0  ...                0.30
#
#         dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# 0                     0.03                    0.17                    0.00
# 1                     0.60                    0.88                    0.00
# 2                     0.05                    0.00                    0.00
# 3                     0.00                    0.03                    0.04
# 4                     0.00                    0.00                    0.00
# ...                    ...                     ...                     ...
# 125968                0.06                    0.00                    0.00
# 125969                0.01                    0.01                    0.00
# 125970                0.06                    0.00                    0.00
# 125971                0.05                    0.00                    0.00
# 125972                0.03                    0.30                    0.00
#
#         dsthostserrorrate  dsthostsrvserrorrate  dsthostrerrorrate  \
# 0                    0.00                  0.00               0.05
# 1                    0.00                  0.00               0.00
# 2                    1.00                  1.00               0.00
# 3                    0.03                  0.01               0.00
# 4                    0.00                  0.00               0.00
# ...                   ...                   ...                ...
# 125968               1.00                  1.00               0.00
# 125969               0.00                  0.00               0.00
# 125970               0.72                  0.00               0.01
# 125971               1.00                  1.00               0.00
# 125972               0.00                  0.00               0.00
#
#         dsthostsrvrerrorrate  attack  lastflag
# 0                       0.00       1        20
# 1                       0.00       1        15
# 2                       0.00       0        19
# 3                       0.01       1        21
# 4                       0.00       1        21
# ...                      ...     ...       ...
# 125968                  0.00       0        20
# 125969                  0.00       1        21
# 125970                  0.00       1        18
# 125971                  0.00       0        20
# 125972                  0.00       1        21
#
# [125973 rows x 39 columns]

# %% [markdown]
# ## Feature Scaling and Train/Test Split

# %%
# All the features apart from Attack are what we are going to use to predict the attack status of the data
# attack = 1 (normal/not an attack) and attack = 0 (attack)
X = data.drop(['attack'],axis=1).to_numpy()

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the data
X_normalized = scaler.fit_transform(X)

Y = data['attack'].to_numpy()
# Splitting X and y testing and training data
# we are taking 20% of the data for testing and 80% of the data for training
X_train, X_test, y_train, y_test = train_test_split(X_normalized, Y, test_size = 0.20)
# reshaping y test and train array
y_train = y_train.reshape(len(y_train),1)
y_test = y_test.reshape(len(y_test),1)

# %% [markdown]
# ## Question 2: Dimensionality Reduction for Visualization

# %% [markdown]
# ##### (a) Use TSNE from the sklearn.manifold library to visualize the data in the test set (X_test) in 2D. In your figure, use color "red" to mark {attack} data points and color "blue" to mark {normal} data points.

# %%
from sklearn.manifold import TSNE
X_tsne = TSNE(n_components=2, random_state=42).fit_transform(X_test)

y_test_flat = np.array(y_test).ravel()

plt.figure(figsize=(8,6))

# attack = 0
plt.scatter(
    X_tsne[y_test_flat == 0, 0],
    X_tsne[y_test_flat == 0, 1],
    c='red',
    label='attack',
    alpha=0.5
)

# normal = 1
plt.scatter(
    X_tsne[y_test_flat == 1, 0],
    X_tsne[y_test_flat == 1, 1],
    c='blue',
    label='normal',
    alpha=0.5
)

plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.title('t-SNE Visualization of Network Anomaly Test Data')
plt.legend()
plt.show()

# %% [markdown]
# ##### (b) Use PCA from the sklearn.decomposition library to visualize the data in the test set (X_test) in 2D. In your figure, use color "red" to mark {attack} data points and color "blue" to mark {normal} data points.

# %%
from sklearn.decomposition import PCA
X_pca = PCA(n_components=2).fit_transform(X_test)

y_test_flat = np.array(y_test).ravel()

plt.figure(figsize=(8,6))

# attack = 0
plt.scatter(
    X_pca[y_test_flat == 0, 0],
    X_pca[y_test_flat == 0, 1],
    c='red',
    label='attack',
    alpha=0.5
)

# normal = 1
plt.scatter(
    X_pca[y_test_flat == 1, 0],
    X_pca[y_test_flat == 1, 1],
    c='blue',
    label='normal',
    alpha=0.5
)

plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('PCA Visualization of Network Anomaly Test Data')
plt.legend()
plt.show()

# %% [markdown]
# ##### (c) Use KernelPCA from the sklearn.decomposition library to visualize the data in the test set (X_test) in 2D. Use radial basis function (rbf) as the kernel. In your figure, use color "red" to mark {attack} data points and color "blue" to mark {normal} data points.

# %%
from sklearn.decomposition import KernelPCA
X_kpca = KernelPCA(
    n_components=2,
    kernel='rbf',
    random_state=42
).fit_transform(X_test)

y_test_flat = np.array(y_test).ravel()

plt.figure(figsize=(8,6))

# attack = 0
plt.scatter(
    X_kpca[y_test_flat == 0, 0],
    X_kpca[y_test_flat == 0, 1],
    c='red',
    label='attack',
    alpha=0.5
)

# normal = 1
plt.scatter(
    X_kpca[y_test_flat == 1, 0],
    X_kpca[y_test_flat == 1, 1],
    c='blue',
    label='normal',
    alpha=0.5
)

plt.xlabel('Kernel PCA Component 1')
plt.ylabel('Kernel PCA Component 2')
plt.title('Kernel PCA (RBF) Visualization of Network Anomaly Test Data')
plt.legend()
plt.show()

# %% [markdown]
# ## Question 3: Implementing a DNN on the dataset

# %% [markdown]
# ##### (a) Implement a deep neural network (DNN) on the Network Anomaly Dataset. Ensure to include two neurons and softmax activation in the output layer of your DNN.

# %%
# Define the DNN model
base_model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(2, activation='softmax')
])

# %% [markdown]
# ##### (b) Compile and train your DNN model on the training set (X_train). Denote the trained model as base_model.

# %%
base_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = base_model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=64,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/20
# 1260/1260 [==============================] - 6s 4ms/step - loss: 0.0370 - accuracy: 0.9891 - val_loss: 0.0107 - val_accuracy: 0.9962
# Epoch 2/20
# 1260/1260 [==============================] - 5s 4ms/step - loss: 0.0099 - accuracy: 0.9964 - val_loss: 0.0096 - val_accuracy: 0.9964
# Epoch 3/20
# 1260/1260 [==============================] - 5s 4ms/step - loss: 0.0078 - accuracy: 0.9971 - val_loss: 0.0142 - val_accuracy: 0.9969
# Epoch 4/20
# 1260/1260 [==============================] - 7s 6ms/step - loss: 0.0066 - accuracy: 0.9976 - val_loss: 0.0081 - val_accuracy: 0.9977
# Epoch 5/20
# 1260/1260 [==============================] - 6s 5ms/step - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.0066 - val_accuracy: 0.9980
# Epoch 6/20
# 1260/1260 [==============================] - 6s 5ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.0059 - val_accuracy: 0.9976
# Epoch 7/20
# 1260/1260 [==============================] - 6s 5ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.0055 - val_accuracy: 0.9979
# Epoch 8/20
# 1260/1260 [==============================] - 6s 5ms/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 0.0057 - val_accuracy: 0.9977
# Epoch 9/20
# 1260/1260 [==============================] - 6s 5ms/step - loss: 0.0042 - accuracy: 0.9984 - val_loss: 0.0058 - val_accuracy: 0.9979
# Epoch 10/20
# 1260/1260 [==============================] - 6s 5ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.0047 - val_accuracy: 0.9985
# Epoch 11/20
# 1260/1260 [==============================] - 5s 4ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.0060 - val_accuracy: 0.9981
# Epoch 12/20
# 1260/1260 [==============================] - 5s 4ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.0047 - val_accuracy: 0.9983
# Epoch 13/20
# 1260/1260 [==============================] - 5s 4ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.0047 - val_accuracy: 0.9984
# Epoch 14/20
# 1260/1260 [==============================] - 5s 4ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0072 - val_accuracy: 0.9982
# Epoch 15/20
# 1260/1260 [==============================] - 5s 4ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.0040 - val_accuracy: 0.9984
# Epoch 16/20
# 1260/1260 [==============================] - 5s 4ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.0040 - val_accuracy: 0.9987
# Epoch 17/20
# 1260/1260 [==============================] - 5s 4ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0054 - val_accuracy: 0.9984
# Epoch 18/20
# 1260/1260 [==============================] - 5s 4ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 0.0048 - val_accuracy: 0.9984
# Epoch 19/20
# 1260/1260 [==============================] - 5s 4ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.0047 - val_accuracy: 0.9987
# Epoch 20/20
# 1260/1260 [==============================] - 5s 4ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.0066 - val_accuracy: 0.9981

# %% [markdown]
# ##### (c) Evaluate the base_model on the test set (X_test) using classification_report and confusion_matrix from the sklearn.metrics library. Report these numbers in your .pdf writeup file using screenshots.

# %%
y_pred_prob = base_model.predict(X_test)

y_pred = np.argmax(y_pred_prob, axis=1)

y_test_flat = y_test.ravel()

print("Classification Report:")
print(classification_report(y_test_flat, y_pred))

cm = confusion_matrix(y_test_flat, y_pred)
print("Confusion Matrix:")
print(cm)

# Optional visualization of confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Base Model')
plt.show()
# Out:
# 788/788 [==============================] - 2s 3ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     11758
#            1       1.00      1.00      1.00     13437
#
#     accuracy                           1.00     25195
#    macro avg       1.00      1.00      1.00     25195
# weighted avg       1.00      1.00      1.00     25195
#
# Confusion Matrix:
# [[11743    15]
#  [   21 13416]]

# %%
# Save the original Keras model to HDF5 file
base_model.save('original_model.h5')

# %% [markdown]
# ## Question 4: Implementing Quantized Model

# %% [markdown]
# ##### (a) Implement Dynamic Range Quantization on the base_model. Designate the resulting quantized ML model as tflite_quant_model.

# %%
base_model = tf.keras.models.load_model('original_model.h5')

def representative_dataset():
    for i in range(100):
        yield [X_train[i:i+1].astype(np.float32)]

converter = tf.lite.TFLiteConverter.from_keras_model(base_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

tflite_quant_model = converter.convert()

with open('quantized_model.tflite', 'wb') as f:
    f.write(tflite_quant_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp6beexfsn/assets
# INFO:tensorflow:Assets written to: /tmp/tmp6beexfsn/assets
# 2026-06-02 16:51:02.427492: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-06-02 16:51:02.428093: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-06-02 16:51:02.430096: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp6beexfsn
# 2026-06-02 16:51:02.431590: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-06-02 16:51:02.431620: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmp6beexfsn
# 2026-06-02 16:51:02.437486: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-06-02 16:51:02.504728: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmp6beexfsn
# 2026-06-02 16:51:02.519290: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 88969 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8

# %%
import os

# Save the quantized model
with open('quantized_model.tflite', 'wb') as f:
    f.write(tflite_quant_model)

# Get the file sizes
original_model_size = os.path.getsize('original_model.h5')
quantized_model_size = os.path.getsize('quantized_model.tflite')

# Print the model sizes
print(f"Original model size: {original_model_size / 1024:.2f} KB")
print(f"Quantized model size: {quantized_model_size / 1024:.2f} KB")
# Out:
# Original model size: 100.01 KB
# Quantized model size: 8.31 KB

# %% [markdown]
# ##### (b) Evaluate the tflite_quant_model on the test set (X_test) using classification_report and confusion_matrix from the sklearn.metrics library. Report these numbers in your .pdf writeup file using screenshots.

# %%
interpreter = tf.lite.Interpreter(model_content=tflite_quant_model)
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

input_scale, input_zero_point = input_details[0]['quantization']
output_scale, output_zero_point = output_details[0]['quantization']

tflite_predictions = []

for i in range(len(X_test)):
    input_data = np.expand_dims(X_test[i], axis=0).astype(np.float32)

    input_data = input_data / input_scale + input_zero_point
    input_data = np.round(input_data).astype(np.int8)

    interpreter.set_tensor(input_details[0]['index'], input_data)
    interpreter.invoke()

    output_data = interpreter.get_tensor(output_details[0]['index'])

    predicted_class = np.argmax(output_data, axis=1)[0]

    tflite_predictions.append(predicted_class)

tflite_predictions = np.array(tflite_predictions)

y_test_flat = np.array(y_test).ravel()

print(classification_report(y_test_flat, tflite_predictions))

cm_tflite = confusion_matrix(y_test_flat, tflite_predictions)
print(cm_tflite)

plt.figure(figsize=(6,5))
sns.heatmap(cm_tflite, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Quantized TFLite Model')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     11758
#            1       0.99      1.00      1.00     13437
#
#     accuracy                           0.99     25195
#    macro avg       0.99      0.99      0.99     25195
# weighted avg       0.99      0.99      0.99     25195
#
# [[11642   116]
#  [   17 13420]]

# %% [markdown]
# ## Converting tflite_model to C and create the header file

# %%
# c_writer is a py file in the same folder and has been imported at the beginning of the notebook
# Reference : https://github.com/ShawnHymel/tinyml-example-anomaly-detection/blob/master/utils/c_writer.py
# We use #04x to pad the output to 2 digits with a 0x prefix
hex_array = [format(val, '#04x') for val in tflite_quant_model]
# Calling function to convert an array into a C string (requires Numpy)
# create_array(np_array, var_type, var_name, line_limit=80, indent=4)
c_model = c_writer.create_array(np.array(hex_array), 'unsigned char', "network_model")
# Calling Function to create a header file with given C code as a string
header_str = c_writer.create_header(c_model, "network_model")

# %%
#Writing to the header file
with open('network_model.h', 'w') as file:
    file.write(header_str)

# %% [markdown]
# ## Generating Samples for Inference on Arduino

# %%
# Converting a sample piece of the X test and y test data to C (for the purpose of ino code (arduino) to load and test
# the sample and compare

Xtest = X_test[0:5,:]
print(c_writer.create_array(Xtest,"float","X_test"))
# Out:
# const unsigned int X_test_dim1 = 5;
# const unsigned int X_test_dim2 = 38;
#
# const float X_test[5][38] = {
#     -0.11024922321249885, 2.219311849644404, -1.1761894520278895,
#     0.7511112872365361, -0.007754404695011096, -0.004900988196303884,
#     -0.08948642202040107, -0.09507567152556495, -0.8092618187059747,
#     -0.011663642603760032, -0.036651869142258646, -0.024436507262009306,
#     -0.01238515036740332, -0.02618002418454278, -0.018609896340735923,
#     -0.04122119759327531, -0.0028174939213690777, -0.0975309439715147,
#     0.2697838052211427, 1.2013691656990784, -0.6372092679572258,
#     -0.6319290328885425, -0.37436223991967527, -0.37443160310530493,
#     0.7712831058493207, -0.349683030873482, -0.37455970440553465,
#     0.7343425609306344, 1.2497210379081434, 1.0664013456654926,
#     -0.3861460041139426, -0.4801968475158174, -0.28910340026287856,
#     -0.6395319051152512, -0.6248707997445304, -0.38763462350750655,
#     -0.3763870260680415, -0.21997021516886575, -0.11024922321249885,
#     -0.12470615670462065, -0.44208308523109213, -2.2235805674567635,
#     -0.00776224074056876, -0.004918644383724874, -0.08948642202040107,
#     -0.09507567152556495, -0.8092618187059747, -0.011663642603760032,
#     -0.036651869142258646, -0.024436507262009306, -0.01238515036740332,
#     -0.02618002418454278, -0.018609896340735923, -0.04122119759327531,
#     -0.0028174939213690777, -0.0975309439715147, -0.7257784945454897,
#     -0.3681102129968653, -0.6372092679572258, -0.6319290328885425,
#     2.7464027950834815, 2.715364578035608, 0.7712831058493207,
#     -0.349683030873482, -0.37455970440553465, -1.6949504156678066,
#     1.2406878020363448, 1.0664013456654926, -0.43907816809041417,
#     -0.25365662769412595, 1.1323183012279232, -0.6395319051152512,
#     -0.6248707997445304, 2.8744095478204597, 2.753913722653446,
#     0.6528228780141483, -0.11024922321249885, -0.12470615670462065,
#     -0.44208308523109213, 0.7511112872365361, -0.007721697722248672,
#     -0.00465405025110609, -0.08948642202040107, -0.09507567152556495,
#     1.2356940323701657, -0.011663642603760032, -0.036651869142258646,
#     -0.024436507262009306, -0.01238515036740332, -0.02618002418454278,
#     -0.018609896340735923, -0.04122119759327531, -0.0028174939213690777,
#     -0.0975309439715147, -0.7257784945454897, -0.3681102129968653,
#     -0.6372092679572258, -0.6319290328885425, -0.37436223991967527,
#     -0.37443160310530493, 0.7712831058493207, -0.349683030873482,
#     -0.37455970440553465, -1.5538296618405114, 1.2587542737799418,
#     1.0664013456654926, -0.43907816809041417, -0.3507452933319937,
#     0.155090881452997, -0.6395319051152512, -0.6248707997445304,
#     -0.38763462350750655, -0.3763870260680415, 0.6528228780141483,
#     -0.10909737284862561, -0.12470615670462065, 1.3931828317609012,
#     0.7511112872365361, -0.007158694883812159, -0.004835585699237399,
#     -0.08948642202040107, -0.09507567152556495, 1.2356940323701657,
#     -0.011663642603760032, -0.036651869142258646, -0.024436507262009306,
#     -0.01238515036740332, -0.02618002418454278, -0.018609896340735923,
#     -0.04122119759327531, -0.0028174939213690777, -0.0975309439715147,
#     -0.7257784945454897, -0.35434285002584825, -0.6372092679572258,
#     -0.6319290328885425, -0.37436223991967527, -0.37443160310530493,
#     0.7712831058493207, -0.349683030873482, 3.4741184775599305,
#     -1.5336695541508978, 0.49996246054886545, 0.2422516787331667,
#     0.24903996360371639, -0.38310818187794965, -0.20026454391970344,
#     -0.6395319051152512, -0.6024325397096294, -0.38763462350750655,
#     -0.3763870260680415, 0.6528228780141483, -0.11024922321249885,
#     -0.12470615670462065, 1.3931828317609012, 0.7511112872365361,
#     -0.007576730879431888, -0.0048353370205413285, -0.08948642202040107,
#     -0.09507567152556495, -0.8092618187059747, -0.011663642603760032,
#     -0.036651869142258646, -0.024436507262009306, -0.01238515036740332,
#     -0.02618002418454278, -0.018609896340735923, -0.04122119759327531,
#     -0.0028174939213690777, -0.0975309439715147, -0.7170454919159579,
#     -0.3681102129968653, -0.6372092679572258, -0.6319290328885425,
#     -0.37436223991967527, -0.37443160310530493, -0.36605989270614575,
#     5.196207521885405, -0.37455970440553465, -0.7373453004111598,
#     -0.10526434286163591, -0.15868599707174857, 0.19610779962724478,
#     -0.4478339589698615, -0.11142568757652836, -0.5720831756644157,
#     -0.6248707997445304, -0.38763462350750655, -0.3763870260680415,
#     0.6528228780141483
# };

# %%
ytest=y_test[0:5]
print(c_writer.create_array(ytest,"uint8_t","y_test"))
# Out:
# const unsigned int y_test_dim1 = 5;
# const unsigned int y_test_dim2 = 1;
#
# const uint8_t y_test[5][1] = {
#     1, 1, 1, 1, 1
# };

# %%
print(base_model.summary())
print(interpreter.get_output_details())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 64)                2496
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dense_6 (Dense)             (None, 16)                528
#
#  dense_7 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 5138 (20.07 KB)
# Trainable params: 5138 (20.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# [{'name': 'StatefulPartitionedCall:0', 'index': 13, 'shape': array([1, 2], dtype=int32), 'shape_signature': array([-1,  2], dtype=int32), 'dtype': <class 'numpy.int8'>, 'quantization': (0.00390625, -128), 'quantization_parameters': {'scales': array([0.00390625], dtype=float32), 'zero_points': array([-128], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]

# %%
interpreter = tf.lite.Interpreter(model_content=tflite_quant_model)
interpreter.allocate_tensors()

print(interpreter.get_input_details())
print(interpreter.get_output_details())
# Out:
# [{'name': 'serving_default_dense_4_input:0', 'index': 0, 'shape': array([ 1, 38], dtype=int32), 'shape_signature': array([-1, 38], dtype=int32), 'dtype': <class 'numpy.int8'>, 'quantization': (0.1283939927816391, -86), 'quantization_parameters': {'scales': array([0.128394], dtype=float32), 'zero_points': array([-86], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# [{'name': 'StatefulPartitionedCall:0', 'index': 13, 'shape': array([1, 2], dtype=int32), 'shape_signature': array([-1,  2], dtype=int32), 'dtype': <class 'numpy.int8'>, 'quantization': (0.00390625, -128), 'quantization_parameters': {'scales': array([0.00390625], dtype=float32), 'zero_points': array([-128], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]

# %%
print(interpreter.get_input_details())
# Out:
# [{'name': 'serving_default_dense_4_input:0', 'index': 0, 'shape': array([ 1, 38], dtype=int32), 'shape_signature': array([-1, 38], dtype=int32), 'dtype': <class 'numpy.int8'>, 'quantization': (0.1283939927816391, -86), 'quantization_parameters': {'scales': array([0.128394], dtype=float32), 'zero_points': array([-86], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]

# %%
#   },
#   {
#     -0.11024922321249885f, -2.468724163053645f, -1.05383839089509f, 0.7511112872365361f, -0.007759174461872282f, -0.004918644383724874f, -0.08948642202040107f, -0.09507567152556495f, -0.8092618187059747f, -0.011663642603760032f, -0.036651869142258646f, -0.024436507262009306f, -0.01238515036740332f, -0.02618002418454278f, -0.018609896340735923f, -0.04122119759327531f, -0.0028174939213690777f, -0.0975309439715147f, -0.7257784945454897f, -0.3681102129968653f, -0.6372092679572258f, -0.6319290328885425f, -0.37436223991967527f, -0.37443160310530493f, 0.7712831058493207f, -0.349683030873482f, -0.37455970440553465f, -1.8259911156502953f, -0.8188899767337195f, 1.0664013456654926f, -0.43907816809041417f, 2.756092007079775f, 8.594782234054632f, -0.6395319051152512f, -0.6248707997445304f, -0.38763462350750655f, -0.3763870260680415f, -0.6563667617603728f
#   },
#   {
#     -0.11024922321249885f, -0.12470615670462065f, -0.44208308523109213f, 0.7511112872365361f, -0.007728341326091039f, -0.0048778610775693475f, -0.08948642202040107f, -0.09507567152556495f, 1.2356940323701657f, -0.011663642603760032f, -0.036651869142258646f, -0.024436507262009306f, -0.01238515036740332f, -0.02618002418454278f, -0.018609896340735923f, -0.04122119759327531f, -0.0028174939213690777f, -0.0975309439715147f, -0.6646474761387667f, -0.18913449437364369f, -0.6372092679572258f, -0.6319290328885425f, -0.37436223991967527f, -0.37443160310530493f, 0.7712831058493207f, -0.349683030873482f, 0.16425524106963055f, -1.7554307387366475f, 1.2587542737799418f, 1.0664013456654926f, -0.43907816809041417f, -0.09184218496434637f, 0.24392973779617205f, -0.6395319051152512f, -0.6248707997445304f, -0.38763462350750655f, -0.3763870260680415f, 0.6528228780141483f
#   },
#   {
#     -0.11024922321249885f, -0.12470615670462065f, -0.44208308523109213f, 0.7511112872365361f, -0.0077099436539121765f, -0.004367572393233121f, -0.08948642202040107f, -0.09507567152556495f, 1.2356940323701657f, -0.011663642603760032f, -0.036651869142258646f, -0.024436507262009306f, -0.01238515036740332f, -0.02618002418454278f, -0.018609896340735923f, -0.04122119759327531f, -0.0028174939213690777f, -0.0975309439715147f, -0.5249194340662569f, -0.0239261387214391f, -0.6372092679572258f, -0.6319290328885425f, -0.37436223991967527f, -0.37443160310530493f, 0.7712831058493207f, -0.349683030873482f, 0.08728167743032118f, 0.7343425609306344f, 1.2587542737799418f, 1.0664013456654926f, -0.43907816809041417f, -0.4801968475158174f, -0.28910340026287856f, -0.6395319051152512f, -0.6248707997445304f, -0.38763462350750655f, -0.3763870260680415f, 0.6528228780141483f
#   },
# };

# %%
ytest = y_test[5:15].ravel()

print("const uint8_t y_test[10] = {")
print("  " + ", ".join([str(int(y)) for y in ytest]))
print("};")
# Out:
# const uint8_t y_test[10] = {
#   1, 1, 0, 1, 1, 0, 1, 0, 1, 1
# };
